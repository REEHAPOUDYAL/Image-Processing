# %%
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt

# %%
def nearest_neighbor_interpolation(image, new_width, new_height):
    original_width, original_height = image.size
    new_image = Image.new("RGB", (new_width, new_height))
    pixels = new_image.load()

    for i in range(new_width):
        for j in range(new_height):
            nearest_x = i * original_width / new_width
            nearest_y = j * original_height / new_height
            pixels[i, j] = image.getpixel((nearest_x, nearest_y))

    return new_image

# %%
image_path = 'lenna'
original_image = Image.open(image_path)

# %%
new_width, new_height = 112 , 112

# %%
resized_image = nearest_neighbor_interpolation(original_image, new_width, new_height)

# %%
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.title('Original Image')
plt.imshow(original_image)
plt.axis('off')
plt.subplot(1, 2, 2)
plt.title('Resized Image (Nearest Neighbor)')
plt.imshow(resized_image)
plt.axis('off')

plt.show()

# %%
#Using Opencv
import cv2
image = image_bgr = cv2.imread('lenna', cv2.IMREAD_COLOR)
image_rgb = cv2.cvtColor(image_bgr, cv2.COLOR_BGR2RGB)

# %%
height, width, _ = image_rgb.shape
new_size = (width // 4, height // 4)
downscaled_image = cv2.resize(image_rgb, new_size, interpolation=cv2.INTER_NEAREST)

# %%
upscaled_image = cv2.resize(image_rgb, (width, height), interpolation=cv2.INTER_NEAREST)

# %%
plt.figure(figsize=(12, 6))

plt.subplot(1, 3, 1)
plt.title('Original Image')
plt.imshow(image_rgb)
plt.axis('off')

plt.subplot(1, 3, 2)
plt.title('Downscaled Image')
plt.imshow(downscaled_image)
plt.axis('off')

plt.subplot(1, 3, 3)
plt.title('Upscaled Image (Nearest Neighbor)')
plt.imshow(upscaled_image)
plt.axis('off')

plt.tight_layout()
plt.show()
